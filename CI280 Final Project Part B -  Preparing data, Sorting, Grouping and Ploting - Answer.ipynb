# %% [markdown]
# # CI280 - Final Project - Part B
# #
# # Data Preparation, Sort, Groupby and Plot( 100 pts)
#
# ## Name

# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib
plt.rc('figure', figsize=(10, 8))

# %%
data = pd.read_csv('data//covid-data.csv')

# %%
# limiting the display rows
pd.set_option('display.max_rows', 5)
data
# Out:
#       iso_code continent       location        date  total_cases  new_cases  \
# 0          AFG      Asia    Afghanistan  2020-01-23          NaN        0.0
# 1          AFG      Asia    Afghanistan  2020-01-24          NaN        0.0
# ...        ...       ...            ...         ...          ...        ...
# 59919      NaN       NaN  International  2020-11-29        721.0        0.0
# 59920      NaN       NaN  International  2020-11-30        721.0        0.0
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                     NaN           NaN         0.0                  NaN  ...
# 1                     NaN           NaN         0.0                  NaN  ...
# ...                   ...           ...         ...                  ...  ...
# 59919                 0.0          15.0         0.0                  0.0  ...
# 59920                 0.0          15.0         0.0                  0.0  ...
#
#        gdp_per_capita  extreme_poverty  cardiovasc_death_rate  \
# 0            1803.987              NaN                597.029
# 1            1803.987              NaN                597.029
# ...               ...              ...                    ...
# 59919             NaN              NaN                    NaN
# 59920             NaN              NaN                    NaN
#
#        diabetes_prevalence  female_smokers  male_smokers  \
# 0                     9.59             NaN           NaN
# 1                     9.59             NaN           NaN
# ...                    ...             ...           ...
# 59919                  NaN             NaN           NaN
# 59920                  NaN             NaN           NaN
#
#        handwashing_facilities  hospital_beds_per_thousand  life_expectancy  \
# 0                      37.746                         0.5            64.83
# 1                      37.746                         0.5            64.83
# ...                       ...                         ...              ...
# 59919                     NaN                         NaN              NaN
# 59920                     NaN                         NaN              NaN
#
#        human_development_index
# 0                        0.498
# 1                        0.498
# ...                        ...
# 59919                      NaN
# 59920                      NaN
#
# [59921 rows x 50 columns]

# %%
df = data[ (data['location'] != 'World') ]
df
# Out:
#       iso_code continent       location        date  total_cases  new_cases  \
# 0          AFG      Asia    Afghanistan  2020-01-23          NaN        0.0
# 1          AFG      Asia    Afghanistan  2020-01-24          NaN        0.0
# ...        ...       ...            ...         ...          ...        ...
# 59919      NaN       NaN  International  2020-11-29        721.0        0.0
# 59920      NaN       NaN  International  2020-11-30        721.0        0.0
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                     NaN           NaN         0.0                  NaN  ...
# 1                     NaN           NaN         0.0                  NaN  ...
# ...                   ...           ...         ...                  ...  ...
# 59919                 0.0          15.0         0.0                  0.0  ...
# 59920                 0.0          15.0         0.0                  0.0  ...
#
#        gdp_per_capita  extreme_poverty  cardiovasc_death_rate  \
# 0            1803.987              NaN                597.029
# 1            1803.987              NaN                597.029
# ...               ...              ...                    ...
# 59919             NaN              NaN                    NaN
# 59920             NaN              NaN                    NaN
#
#        diabetes_prevalence  female_smokers  male_smokers  \
# 0                     9.59             NaN           NaN
# 1                     9.59             NaN           NaN
# ...                    ...             ...           ...
# 59919                  NaN             NaN           NaN
# 59920                  NaN             NaN           NaN
#
#        handwashing_facilities  hospital_beds_per_thousand  life_expectancy  \
# 0                      37.746                         0.5            64.83
# 1                      37.746                         0.5            64.83
# ...                       ...                         ...              ...
# 59919                     NaN                         NaN              NaN
# 59920                     NaN                         NaN              NaN
#
#        human_development_index
# 0                        0.498
# 1                        0.498
# ...                        ...
# 59919                      NaN
# 59920                      NaN
#
# [59607 rows x 50 columns]

# %%
# Show number of records 
import random
number = random.randint(0,10000)
print("You name , id: ", number )
print('------------------------------')
# Out:
# You name , id:  9947
# ------------------------------

# %% [markdown]
# ## C) Handing Missing Data and Ploting (20 pts)
#
# ### use isnull() vs. notnull()
# ### use dropna
# ### use replacena

# %%
# show last five rows
df.tail()
# Out:
#       iso_code continent       location        date  total_cases  new_cases  \
# 56316      NaN       NaN  International  2020-11-08        696.0        NaN
# 56317      NaN       NaN  International  2020-11-09        696.0        NaN
# 56318      NaN       NaN  International  2020-11-10        696.0        NaN
# 56319      NaN       NaN  International  2020-11-11        696.0        NaN
# 56320      NaN       NaN  International  2020-11-12        696.0        NaN
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 56316                 NaN           7.0         NaN                  NaN  ...
# 56317                 NaN           7.0         NaN                  NaN  ...
# 56318                 NaN           7.0         NaN                  NaN  ...
# 56319                 NaN           7.0         NaN                  NaN  ...
# 56320                 NaN           7.0         NaN                  NaN  ...
#
#        gdp_per_capita  extreme_poverty  cardiovasc_death_rate  \
# 56316             NaN              NaN                    NaN
# 56317             NaN              NaN                    NaN
# 56318             NaN              NaN                    NaN
# 56319             NaN              NaN                    NaN
# 56320             NaN              NaN                    NaN
#
#        diabetes_prevalence  female_smokers  male_smokers  \
# 56316                  NaN             NaN           NaN
# 56317                  NaN             NaN           NaN
# 56318                  NaN             NaN           NaN
# 56319                  NaN             NaN           NaN
# 56320                  NaN             NaN           NaN
#
#        handwashing_facilities  hospital_beds_per_thousand  life_expectancy  \
# 56316                     NaN                         NaN              NaN
# 56317                     NaN                         NaN              NaN
# 56318                     NaN                         NaN              NaN
# 56319                     NaN                         NaN              NaN
# 56320                     NaN                         NaN              NaN
#
#        human_development_index
# 56316                      NaN
# 56317                      NaN
# 56318                      NaN
# 56319                      NaN
# 56320                      NaN
#
# [5 rows x 49 columns]

# %%
# show the number of rows and columns of datafram 
df.shape
number = random.randint(0,10000)
print("You name , id: ", number )
print('------------------------------')

# 1) Show the number of records which have no data for continent ( 2 pts)
#    Show the the last five those records 

print('The number records missing data for continent')
print(len(df[df.continent.isnull()]))

df[df.continent.isnull()].tail()
# Out:
# You name , id:  5035
# ------------------------------
# The number records missing data for continent
# 313
#       iso_code continent       location        date  total_cases  new_cases  \
# 59916      NaN       NaN  International  2020-11-26        721.0        0.0
# 59917      NaN       NaN  International  2020-11-27        721.0        0.0
# 59918      NaN       NaN  International  2020-11-28        721.0        0.0
# 59919      NaN       NaN  International  2020-11-29        721.0        0.0
# 59920      NaN       NaN  International  2020-11-30        721.0        0.0
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 59916                 0.0          15.0         0.0                  0.0  ...
# 59917                 0.0          15.0         0.0                  0.0  ...
# 59918                 0.0          15.0         0.0                  0.0  ...
# 59919                 0.0          15.0         0.0                  0.0  ...
# 59920                 0.0          15.0         0.0                  0.0  ...
#
#        gdp_per_capita  extreme_poverty  cardiovasc_death_rate  \
# 59916             NaN              NaN                    NaN
# 59917             NaN              NaN                    NaN
# 59918             NaN              NaN                    NaN
# 59919             NaN              NaN                    NaN
# 59920             NaN              NaN                    NaN
#
#        diabetes_prevalence  female_smokers  male_smokers  \
# 59916                  NaN             NaN           NaN
# 59917                  NaN             NaN           NaN
# 59918                  NaN             NaN           NaN
# 59919                  NaN             NaN           NaN
# 59920                  NaN             NaN           NaN
#
#        handwashing_facilities  hospital_beds_per_thousand  life_expectancy  \
# 59916                     NaN                         NaN              NaN
# 59917                     NaN                         NaN              NaN
# 59918                     NaN                         NaN              NaN
# 59919                     NaN                         NaN              NaN
# 59920                     NaN                         NaN              NaN
#
#        human_development_index
# 59916                      NaN
# 59917                      NaN
# 59918                      NaN
# 59919                      NaN
# 59920                      NaN
#
# [5 rows x 50 columns]

# %%
df[ df.continent.isnull()]
# Out:
#       iso_code continent       location        date  total_cases  new_cases  \
# 59608      NaN       NaN  International  2020-01-23          NaN        0.0
# 59609      NaN       NaN  International  2020-01-24          NaN        0.0
# ...        ...       ...            ...         ...          ...        ...
# 59919      NaN       NaN  International  2020-11-29        721.0        0.0
# 59920      NaN       NaN  International  2020-11-30        721.0        0.0
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 59608                 NaN           NaN         0.0                  NaN  ...
# 59609                 NaN           NaN         0.0                  NaN  ...
# ...                   ...           ...         ...                  ...  ...
# 59919                 0.0          15.0         0.0                  0.0  ...
# 59920                 0.0          15.0         0.0                  0.0  ...
#
#        gdp_per_capita  extreme_poverty  cardiovasc_death_rate  \
# 59608             NaN              NaN                    NaN
# 59609             NaN              NaN                    NaN
# ...               ...              ...                    ...
# 59919             NaN              NaN                    NaN
# 59920             NaN              NaN                    NaN
#
#        diabetes_prevalence  female_smokers  male_smokers  \
# 59608                  NaN             NaN           NaN
# 59609                  NaN             NaN           NaN
# ...                    ...             ...           ...
# 59919                  NaN             NaN           NaN
# 59920                  NaN             NaN           NaN
#
#        handwashing_facilities  hospital_beds_per_thousand  life_expectancy  \
# 59608                     NaN                         NaN              NaN
# 59609                     NaN                         NaN              NaN
# ...                       ...                         ...              ...
# 59919                     NaN                         NaN              NaN
# 59920                     NaN                         NaN              NaN
#
#        human_development_index
# 59608                      NaN
# 59609                      NaN
# ...                        ...
# 59919                      NaN
# 59920                      NaN
#
# [313 rows x 50 columns]

# %%
number = random.randint(0,10000)
print("You name , id: ", number )
print('------------------------------')


# 2-3) Show the number records of miss data for continent and iso_code (2 pts)
#    Show the the last five those records ( 2 pts)

print('The number records missing data for continent and iso_code')

print( len(df[df.continent.isnull() & df.iso_code.isnull()]  ))
df[df.continent.isnull() & df.iso_code.isnull()].tail()
# Out:
# You name , id:  3404
# ------------------------------
# The number records missing data for continent and iso_code
# 313
#       iso_code continent       location        date  total_cases  new_cases  \
# 59916      NaN       NaN  International  2020-11-26        721.0        0.0
# 59917      NaN       NaN  International  2020-11-27        721.0        0.0
# 59918      NaN       NaN  International  2020-11-28        721.0        0.0
# 59919      NaN       NaN  International  2020-11-29        721.0        0.0
# 59920      NaN       NaN  International  2020-11-30        721.0        0.0
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 59916                 0.0          15.0         0.0                  0.0  ...
# 59917                 0.0          15.0         0.0                  0.0  ...
# 59918                 0.0          15.0         0.0                  0.0  ...
# 59919                 0.0          15.0         0.0                  0.0  ...
# 59920                 0.0          15.0         0.0                  0.0  ...
#
#        gdp_per_capita  extreme_poverty  cardiovasc_death_rate  \
# 59916             NaN              NaN                    NaN
# 59917             NaN              NaN                    NaN
# 59918             NaN              NaN                    NaN
# 59919             NaN              NaN                    NaN
# 59920             NaN              NaN                    NaN
#
#        diabetes_prevalence  female_smokers  male_smokers  \
# 59916                  NaN             NaN           NaN
# 59917                  NaN             NaN           NaN
# 59918                  NaN             NaN           NaN
# 59919                  NaN             NaN           NaN
# 59920                  NaN             NaN           NaN
#
#        handwashing_facilities  hospital_beds_per_thousand  life_expectancy  \
# 59916                     NaN                         NaN              NaN
# 59917                     NaN                         NaN              NaN
# 59918                     NaN                         NaN              NaN
# 59919                     NaN                         NaN              NaN
# 59920                     NaN                         NaN              NaN
#
#        human_development_index
# 59916                      NaN
# 59917                      NaN
# 59918                      NaN
# 59919                      NaN
# 59920                      NaN
#
# [5 rows x 50 columns]

# %%
res['population'].isnull()
# Out:
# 7202    False
# 7203    False
#         ...
# 7513    False
# 7514    False
# Name: population, Length: 313, dtype: bool

# %%
number = random.randint(0,10000)
print("You name , id: ", number )
print('------------------------------')



# 4-5) For the records for Bazil, which columns has missing data (4 pts)
res = df[df['location']=='Brazil']
res

col_names = res.columns
col_names

print('The following columns ar missing data for Brazil')

print(' Column Name \t\t\t\tMissing Data')
print('------------------------------------------------')
for col_name in col_names:
    num = len(   res[ res[col_name].isnull() ] )
    if num > 0 :
        print( '{0: <40}'.format(col_name) , num)
# Out:
# You name , id:  1341
# ------------------------------
# The following columns ar missing data for Brazil
#  Column Name 				Missing Data
# ------------------------------------------------
# total_cases                              34
# new_cases_smoothed                       5
# total_deaths                             54
# new_deaths_smoothed                      5
# total_cases_per_million                  34
# new_cases_smoothed_per_million           5
# total_deaths_per_million                 54
# new_deaths_smoothed_per_million          5
# reproduction_rate                        61
# icu_patients                             313
# icu_patients_per_million                 313
# hosp_patients                            313
# hosp_patients_per_million                313
# weekly_icu_admissions                    313
# weekly_icu_admissions_per_million        313
# weekly_hosp_admissions                   313
# weekly_hosp_admissions_per_million       313
# total_tests                              297
# new_tests                                313
# total_tests_per_thousand                 297
# new_tests_per_thousand                   313
# new_tests_smoothed                       231
# new_tests_smoothed_per_thousand          231
# positive_rate                            313
# tests_per_case                           313
# tests_units                              216
# stringency_index                         21
# handwashing_facilities                   313

# %%
number = random.randint(0,10000)
print("You name , id: ", number )
print('------------------------------')


#df.columns

df.shape
# .dropna() vs. . dropna(how='all')

# 6) For the records for Bazil, show the result after droping rows which have at least one NaN data in the dataset ()  (2 pts)
res = df[df['location']=='Brazil']
res
cleaned = res.dropna()

print('After using .dropn(), total records: ')
print(len(cleaned))
# Out:
# You name , id:  3479
# ------------------------------
# After using .dropn(), total records:
# 0

# %%
number = random.randint(0,10000)
print("You name , id: ", number )
print('------------------------------')

# 7) For the records for Bazil, show the result after after droping rows which all data is NaN in the dataset ()  (2 pts)
res = df[df['location']=='Brazil']
res
cleaned = res.dropna(how='all')

print("After using .dropna(how='all'), total records:")
print(len(cleaned))
#cleaned
# Out:
# You name , id:  6604
# ------------------------------
# After using .dropna(how='all'), total records:
# 313

# %%
number = random.randint(0,10000)
print("You name , id: ", number )
print('------------------------------')

print(df.shape)
print('Original row number:', len(df))

# 8) Show the result after droping the rows which continent or iso data is missing in the dataset
#    How many rows are droped. (2 pts)

cleaned_data = df[df.continent.notnull() & df.iso_code.notnull()]
bad_data = df[df.continent.isnull() | df.iso_code.isnull()]
print("After droping all missing data of continent or iso in the dataset")
print('New dataset included record number:', len(cleaned_data))
print('The number of rows dropped:', len(bad_data))
# Out:
# You name , id:  8801
# ------------------------------
# (59607, 50)
# Original row number: 59607
# After droping all missing data of continent or iso in the dataset
# New dataset included record number: 59294
# The number of rows dropped: 313

# %%
res = df[df['location']=='Brazil']
res[['location','handwashing_facilities']]
# Out:
#      location  handwashing_facilities
# 7202   Brazil                     NaN
# 7203   Brazil                     NaN
# ...       ...                     ...
# 7513   Brazil                     NaN
# 7514   Brazil                     NaN
#
# [313 rows x 2 columns]

# %%
number = random.randint(0,10000)
print("You name , id: ", number )
print('------------------------------')


# 9) Show Brazil's handwashing_facilities information
#    Show the average of handwashing_facilities of worldwide level

import random
number = random.randint(0,10000)
print("You name , id: ", number )
print('------------------------------')

#print(df['handwashing_facilities'].describe())


print("Before handwashing_facilities values are missing in Brazil")
res = df[df['location']=='Brazil']
print(len(res))
data = res[res['handwashing_facilities'].isnull()] [['location','date','handwashing_facilities']]   
print(data)


# For Brazil ,replace handwashing_facilities value as average of worldwide level
avg = df['handwashing_facilities'].mean()


#data= data['handwashing_facilities'].fillna(avg)


print('The average of handwashing_facilities of worldwide:', format(avg, '.0f'))
# Out:
# You name , id:  5342
# ------------------------------
# You name , id:  836
# ------------------------------
# Before handwashing_facilities values are missing in Brazil
# 313
#      location        date  handwashing_facilities
# 7202   Brazil  2020-01-23                     NaN
# 7203   Brazil  2020-01-24                     NaN
# ...       ...         ...                     ...
# 7513   Brazil  2020-11-29                     NaN
# 7514   Brazil  2020-11-30                     NaN
#
# [313 rows x 3 columns]
# The average of handwashing_facilities of worldwide: 50

# %%
number = random.randint(0,10000)
print("You name , id: ", number )
print('------------------------------')

import math

# 10) For Brazil, handwashing_facilities data is missing
#    Replace average handwashing_facilities data of worldwide level  for Brazil(2 pts)

res = df[df['location']=='Brazil']
avg = df['handwashing_facilities'].mean()
avg = math.floor(avg )

print("Now handwashing_facilities values are replace by the average of worldwide level")
data

res['handwashing_facilities'].fillna(avg, inplace=True)
res[['location','date','handwashing_facilities']]
# Out:
# You name , id:  8276
# ------------------------------
# Now handwashing_facilities values are replace by the average of worldwide level
#      location        date  handwashing_facilities
# 7202   Brazil  2020-01-23                    50.0
# 7203   Brazil  2020-01-24                    50.0
# ...       ...         ...                     ...
# 7513   Brazil  2020-11-29                    50.0
# 7514   Brazil  2020-11-30                    50.0
#
# [313 rows x 3 columns]

# %% [markdown]
# # D) Sorting, Grouping and Plotting (30 points)
#
# ## df.sort_values(by=['a','b'], ascending = True)
# ## df.sort_index()
# ## df.groupby( )

# %%
number = random.randint(0,10000)
print("You name , id: ", number )
print('------------------------------')
import matplotlib.pyplot as plt

# 1)  (3 pts) Find the top 10 countries which have the most covid cases

# Group all cases by location , become series
cases = df.groupby(df.location).new_cases.sum()
cases = cases.sort_values(ascending = False)
cases

res = cases.head(10)
#print(res)
countries = res.index

print('10 countries which have the most covid cases')
print('Country              covid cases')
print('------------------------------------------------')
for country in countries:
    print('{0: <20}'.format(country), '\t', format(res[country],'.0f'))
# Out:
# You name , id:  3426
# ------------------------------
# 10 countries which have the most covid cases
# Country              covid cases
# ------------------------------------------------
# United States        	 13541220
# India                	 9462809
# Brazil               	 6335878
# Russia               	 2275936
# France               	 2275016
# Spain                	 1648187
# United Kingdom       	 1633733
# Italy                	 1601554
# Argentina            	 1424533
# Colombia             	 1316806

# %%
number = random.randint(0,10000)
print("You name , id: ", number )
print('------------------------------')


# 2) Use bar chart to show the top 10 countries which have the most covid cases. (3 pts)

res = cases.head(10)
res

print(res.index)
print(res.values)

res.plot(kind='bar', title='10 countries which have the most covid cases')
# Out:
# You name , id:  2406
# ------------------------------
# Index(['United States', 'India', 'Brazil', 'Russia', 'France', 'Spain',
#        'United Kingdom', 'Italy', 'Argentina', 'Colombia'],
#       dtype='object', name='location')
# [13541220.  9462809.  6335878.  2275936.  2275016.  1648187.  1633733.
#   1601554.  1424533.  1316806.]

# %%
number = random.randint(0,10000)
print("You name , id: ", number )
print('------------------------------')

# (3  pts)

# 3) Show int worldwide, which ten day has the most new cases? 

#    Use line chart to show the top 10 days which have the most new covid cases 

# Group all cases by location , become series
cases = df.groupby(df.date).new_cases.sum()
cases = cases.sort_values(ascending = False)
#print(cases)

res = cases.head(10)
res = res.sort_index()
#print(res)
days = res.index

print('Ten days which have the most covid cases')
print('Date              covid cases')
print('------------------------------------------------')
for day in days:
    print(day, '\t', format(res[day],'.0f'))
    
    
# Draw bar chart
#  Add tilte, xlabel, ylabes
plt.title("Top ten days which have the most new covid cases")
plt.xlabel("Date")
plt.ylabel("Numbers")

plt.plot(res.index,res.values, color='b')
#
res.plot(kind='line', rot=45,linestyle='dashed', marker='o')
# Out:
# You name , id:  6094
# ------------------------------
# Ten days which have the most covid cases
# Date              covid cases
# ------------------------------------------------
# 2020-11-06 	 641953
# 2020-11-11 	 644986
# 2020-11-12 	 647297
# 2020-11-13 	 648785
# 2020-11-17 	 608102
# 2020-11-18 	 623670
# 2020-11-19 	 650567
# 2020-11-20 	 666146
# 2020-11-25 	 632945
# 2020-11-27 	 671885

# %%
number = random.randint(0,10000)
print("You name , id: ", number )
print('------------------------------')

# (3  pts)

# 4) On 2020-11-30, which ten countries has the most new cases? 

#    Use bar chart to show the top 10 locations which have the most new covid cases 

res = df[df.date=='2020-11-30']

# Sorting cases 
cases = res.sort_values(by='new_cases', ascending = False)

res = cases.head(10)[['location','new_cases']]
res = res.sort_index()
#print(res)


# Display dataframe
print('On 2020-11-30')
print('10 countries which have the most covid cases on 2020-11-30')
print('Country              covid cases')
print('------------------------------------------------')


for i in res.index:
    country = res['location'][i]
    new_cases = res['new_cases'][i]
    print('{0: <20}'.format(country), '\t', format(new_cases,'.0f'))




# Draw bar chart
#  Add tilte, xlabel, ylabes
plt.title("'10 countries which have the most covid cases on 2020-11-30'")
plt.xlabel("Date")
plt.ylabel("Numbers")

plt.bar(res['location'],res['new_cases'], color='b')
#
#res.plot(kind='line', rot=45,linestyle='dashed', marker='o')
# Out:
# You name , id:  9900
# ------------------------------
# On 2020-11-30
# 10 countries which have the most covid cases on 2020-11-30
# Country              covid cases
# ------------------------------------------------
# Brazil               	 21138
# Germany              	 14221
# Spain                	 19979
# United Kingdom       	 12428
# India                	 31118
# Iran                 	 13321
# Italy                	 16376
# Russia               	 26046
# Turkey               	 31219
# United States        	 157901
# <BarContainer object of 10 artists>

# %%
number = random.randint(0,10000)
print("You name , id: ", number )
print('------------------------------')

# (3  pts)
#  5)  Show last seven days, the new cases in Brazil (Chose one country),
#      Plot a line chart

cases = df[df.location=='Brazil'].sort_values(by ='date', ascending=True)
cases
res = cases[['date', 'new_cases']].tail(7)

print('\nIn the past seven days, the new cases in Brazil')
print('Date             covid cases')
print('------------------------------------------')
dates = res['date']
for i in res.index:
    print(res['date'][i], '\t',  format(res['new_cases'][i], '.0f'))

    
plt.title("new covid cases in Past ten days in Brazil ")
plt.xlabel("Date")
plt.ylabel("Numbers")

plt.plot(res['date'],res['new_cases'], color='b')
# Out:
# You name , id:  926
# ------------------------------
#
# In the past seven days, the new cases in Brazil
# Date             covid cases
# ------------------------------------------
# 2020-11-24 	 31100
# 2020-11-25 	 47898
# 2020-11-26 	 37614
# 2020-11-27 	 34130
# 2020-11-28 	 51922
# 2020-11-29 	 24468
# 2020-11-30 	 21138

# %%
number = random.randint(0,10000)
print("You name , id: ", number )
print('------------------------------')


# 6-7) Group by continent, show total of new covid cases for each continent and sorted by total number (3 pts)
#      Plot the result by pie chart (3 pts)
df
res = df.groupby(df.continent).new_cases.sum().sort_values(ascending=False)
#print(res)

print('Total covid new cases by Continent')
print('-----------------------------------')'
names = res.index
for name in names:
    print('{0: <20}'.format(name), '\t', format(res[name],'.0f'))
    

res.plot(kind='pie', title='Covid new cases by Continent',autopct='%1.1f%%')
# Out:
# Total covid new cases by Continent
# Europe               	 17342381
# Asia                 	 16748512
# North America        	 15809570
# South America        	 11130276
# Africa               	 2174098
# Oceania              	 30691

# %%
res
# Out:
#             location    population
# 10332          China  1.439324e+09
# 24490          India  1.380004e+09
# ...              ...           ...
# 56476        Vatican  8.090000e+02
# 59920  International           NaN
#
# [190 rows x 2 columns]

# %%
number = random.randint(0,10000)
print("You name , id: ", number )
print('------------------------------')

# 8) Show the top 10 countries which have the most population  (3 pts)
df

res = df[df.date=='2020-11-30'][['location','population']].sort_values(by ='population', ascending = False)
res = res.head(10)
#print(res)
res.index

print('Top 10 countries which have the most POPULATION')
for i in res.index:
    print('{0: <20}'.format(res['location'][i]), format(res['population'][i], '.0f'))

# reindex
res2 = res.set_index('location')

#print(res2)

res2.plot(kind='bar', title='Top 10 countries which have the most POPULATION')
# Out:
# You name , id:  6028
# ------------------------------
# Top 10 countries which have the most POPULATION
# China                1439323774
# India                1380004385
# United States        331002647
# Indonesia            273523621
# Pakistan             220892331
# Brazil               212559409
# Nigeria              206139587
# Bangladesh           164689383
# Russia               145934460
# Mexico               128932753

# %%
plt.rc('figure', figsize=(10, 8))

number = random.randint(0,10000)
print("You name , id: ", number )
print('------------------------------')

# 9-10) Show the world poplation
#      Show the  population by each continent and show it as pie chart (6 pts)

data = df[df.date=='2020-11-30']
pop_sum = data['population'].sum()
print('the world poplation', pop_sum)


data = df[df.date=='2020-11-30'][['continent','location','date','population']]
#print(data)

res = df.groupby([df.continent]).population.sum()

#print(res)

#df.columns
print('population by Continent')
print('-----------------------------------')
names = res.index
for name in names:
    print('{0: <20}'.format(name), '\t', format(res[name],'.0f'))
    

res.plot(kind='pie', title='Population by Continent',autopct='%1.1f%%')
# Out:
# You name , id:  6964
# ------------------------------
# the world poplation 7746825445.0
# population by Continent
# -----------------------------------
# Africa               	 419458779069
# Asia                 	 1444009233992
# Europe               	 234262937267
# North America        	 187106204973
# Oceania              	 12906308824
# South America        	 134733230991
