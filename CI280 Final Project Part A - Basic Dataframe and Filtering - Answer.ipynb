# %% [markdown]
# # CI280 Final Project: ( 100 pts)
# # Par A: Basic Dataframe
# #
#
# ## Name
# ### Student ID:

# %%
# %matplotlib inline
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('data//covid-data.csv')

# %%
# limiting the display rows
pd.set_option('display.max_rows', 5)
data
# Out:
#       iso_code continent       location        date  total_cases  new_cases  \
# 0          AFG      Asia    Afghanistan  2020-01-23          NaN        0.0
# 1          AFG      Asia    Afghanistan  2020-01-24          NaN        0.0
# ...        ...       ...            ...         ...          ...        ...
# 59919      NaN       NaN  International  2020-11-29        721.0        0.0
# 59920      NaN       NaN  International  2020-11-30        721.0        0.0
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                     NaN           NaN         0.0                  NaN  ...
# 1                     NaN           NaN         0.0                  NaN  ...
# ...                   ...           ...         ...                  ...  ...
# 59919                 0.0          15.0         0.0                  0.0  ...
# 59920                 0.0          15.0         0.0                  0.0  ...
#
#        gdp_per_capita  extreme_poverty  cardiovasc_death_rate  \
# 0            1803.987              NaN                597.029
# 1            1803.987              NaN                597.029
# ...               ...              ...                    ...
# 59919             NaN              NaN                    NaN
# 59920             NaN              NaN                    NaN
#
#        diabetes_prevalence  female_smokers  male_smokers  \
# 0                     9.59             NaN           NaN
# 1                     9.59             NaN           NaN
# ...                    ...             ...           ...
# 59919                  NaN             NaN           NaN
# 59920                  NaN             NaN           NaN
#
#        handwashing_facilities  hospital_beds_per_thousand  life_expectancy  \
# 0                      37.746                         0.5            64.83
# 1                      37.746                         0.5            64.83
# ...                       ...                         ...              ...
# 59919                     NaN                         NaN              NaN
# 59920                     NaN                         NaN              NaN
#
#        human_development_index
# 0                        0.498
# 1                        0.498
# ...                        ...
# 59919                      NaN
# 59920                      NaN
#
# [59921 rows x 50 columns]

# %% [markdown]
# # A) Basic Dataframe: Statistics in the world (20 points)

# %%
# Show number of records 
import random
number = random.randint(0,10000)
print("You name , id: ", number )
print('------------------------------')

print("Number of records:" ,len(df))
df
# Out:
# You name , id:  1883
# ------------------------------
# Number of records: 56003
#       iso_code      continent       location        date  total_cases  \
# 0          ABW  North America          Aruba  2020-03-13          2.0
# 1          ABW  North America          Aruba  2020-03-19          NaN
# ...        ...            ...            ...         ...          ...
# 56319      NaN            NaN  International  2020-11-11        696.0
# 56320      NaN            NaN  International  2020-11-12        696.0
#
#        new_cases  new_cases_smoothed  total_deaths  new_deaths  \
# 0            2.0                 NaN           NaN         0.0
# 1            NaN               0.286           NaN         NaN
# ...          ...                 ...           ...         ...
# 56319        NaN                 NaN           7.0         NaN
# 56320        NaN                 NaN           7.0         NaN
#
#        new_deaths_smoothed  ...  gdp_per_capita  extreme_poverty  \
# 0                      NaN  ...       35973.781              NaN
# 1                      0.0  ...       35973.781              NaN
# ...                    ...  ...             ...              ...
# 56319                  NaN  ...             NaN              NaN
# 56320                  NaN  ...             NaN              NaN
#
#        cardiovasc_death_rate  diabetes_prevalence  female_smokers  \
# 0                        NaN                11.62             NaN
# 1                        NaN                11.62             NaN
# ...                      ...                  ...             ...
# 56319                    NaN                  NaN             NaN
# 56320                    NaN                  NaN             NaN
#
#        male_smokers  handwashing_facilities  hospital_beds_per_thousand  \
# 0               NaN                     NaN                         NaN
# 1               NaN                     NaN                         NaN
# ...             ...                     ...                         ...
# 56319           NaN                     NaN                         NaN
# 56320           NaN                     NaN                         NaN
#
#        life_expectancy  human_development_index
# 0                76.29                      NaN
# 1                76.29                      NaN
# ...                ...                      ...
# 56319              NaN                      NaN
# 56320              NaN                      NaN
#
# [56003 rows x 49 columns]

# %%
df = data[data['location'] != 'World']
df
# Out:
#       iso_code continent       location        date  total_cases  new_cases  \
# 0          AFG      Asia    Afghanistan  2020-01-23          NaN        0.0
# 1          AFG      Asia    Afghanistan  2020-01-24          NaN        0.0
# ...        ...       ...            ...         ...          ...        ...
# 59919      NaN       NaN  International  2020-11-29        721.0        0.0
# 59920      NaN       NaN  International  2020-11-30        721.0        0.0
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                     NaN           NaN         0.0                  NaN  ...
# 1                     NaN           NaN         0.0                  NaN  ...
# ...                   ...           ...         ...                  ...  ...
# 59919                 0.0          15.0         0.0                  0.0  ...
# 59920                 0.0          15.0         0.0                  0.0  ...
#
#        gdp_per_capita  extreme_poverty  cardiovasc_death_rate  \
# 0            1803.987              NaN                597.029
# 1            1803.987              NaN                597.029
# ...               ...              ...                    ...
# 59919             NaN              NaN                    NaN
# 59920             NaN              NaN                    NaN
#
#        diabetes_prevalence  female_smokers  male_smokers  \
# 0                     9.59             NaN           NaN
# 1                     9.59             NaN           NaN
# ...                    ...             ...           ...
# 59919                  NaN             NaN           NaN
# 59920                  NaN             NaN           NaN
#
#        handwashing_facilities  hospital_beds_per_thousand  life_expectancy  \
# 0                      37.746                         0.5            64.83
# 1                      37.746                         0.5            64.83
# ...                       ...                         ...              ...
# 59919                     NaN                         NaN              NaN
# 59920                     NaN                         NaN              NaN
#
#        human_development_index
# 0                        0.498
# 1                        0.498
# ...                        ...
# 59919                      NaN
# 59920                      NaN
#
# [59607 rows x 50 columns]

# %%
#1) Show all the column names (2 pts)

number = random.randint(0,10000)
print("You name , id: ", number )
print('------------------------------')

names = df.columns
names

print("Show all the column names")
for name in names:
    print(name)
# Out:
# You name , id:  5100
# ------------------------------
# Show all the column names
# iso_code
# continent
# location
# date
# total_cases
# new_cases
# new_cases_smoothed
# total_deaths
# new_deaths
# new_deaths_smoothed
# total_cases_per_million
# new_cases_per_million
# new_cases_smoothed_per_million
# total_deaths_per_million
# new_deaths_per_million
# new_deaths_smoothed_per_million
# icu_patients
# icu_patients_per_million
# hosp_patients
# hosp_patients_per_million
# weekly_icu_admissions
# weekly_icu_admissions_per_million
# weekly_hosp_admissions
# weekly_hosp_admissions_per_million
# total_tests
# new_tests
# total_tests_per_thousand
# new_tests_per_thousand
# new_tests_smoothed
# new_tests_smoothed_per_thousand
# tests_per_case
# positive_rate
# tests_units
# stringency_index
# population
# population_density
# median_age
# aged_65_older
# aged_70_older
# gdp_per_capita
# extreme_poverty
# cardiovasc_death_rate
# diabetes_prevalence
# female_smokers
# male_smokers
# handwashing_facilities
# hospital_beds_per_thousand
# life_expectancy
# human_development_index

# %%
#2) Show all the continent's names (remove the duplicate, and NaN value) (2 pts)

number = random.randint(0,10000)
print("You name , id: ", number )
print('------------------------------')

names = df['continent'].unique()

print("Number of continents")
print(len(names))
print("Show all the continent names:")
for name in names:
    if pd.notnull(name):
        print(name)
# Out:
# You name , id:  6211
# ------------------------------
# Number of continents
# 7
# Show all the continent names:
# North America
# Asia
# Africa
# Europe
# South America
# Oceania

# %%
#3) How many records for the location 'World'
#  Show last five rows from the location  'world'  (2 pts)

world = df[df['location'] == 'World']

print("Records for the location 'World'" ,len(world))
world.tail(5)
# Out:
# Records for the location 'World' 318
#        iso_code continent location        date  total_cases  new_cases  \
# 55998  OWID_WRL       NaN    World  2020-11-08   49964987.0   573453.0
# 55999  OWID_WRL       NaN    World  2020-11-09   50483176.0   518189.0
# 56000  OWID_WRL       NaN    World  2020-11-10   51036867.0   553691.0
# 56001  OWID_WRL       NaN    World  2020-11-11   51584350.0   547483.0
# 56002  OWID_WRL       NaN    World  2020-11-12   52143259.0   558909.0
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 55998          540075.429     1250607.0      7208.0             7720.143  ...
# 55999          544509.143     1256739.0      6132.0             7835.143  ...
# 56000          556380.143     1264906.0      8167.0             8129.714  ...
# 56001          562455.429     1274858.0      9952.0             8145.143  ...
# 56002          560909.429     1284610.0      9752.0             8243.714  ...
#
#        gdp_per_capita  extreme_poverty  cardiovasc_death_rate  \
# 55998       15469.207             10.0                 233.07
# 55999       15469.207             10.0                 233.07
# 56000       15469.207             10.0                 233.07
# 56001       15469.207             10.0                 233.07
# 56002       15469.207             10.0                 233.07
#
#        diabetes_prevalence  female_smokers  male_smokers  \
# 55998                 8.51           6.434        34.635
# 55999                 8.51           6.434        34.635
# 56000                 8.51           6.434        34.635
# 56001                 8.51           6.434        34.635
# 56002                 8.51           6.434        34.635
#
#        handwashing_facilities  hospital_beds_per_thousand  life_expectancy  \
# 55998                   60.13                       2.705            72.58
# 55999                   60.13                       2.705            72.58
# 56000                   60.13                       2.705            72.58
# 56001                   60.13                       2.705            72.58
# 56002                   60.13                       2.705            72.58
#
#        human_development_index
# 55998                      NaN
# 55999                      NaN
# 56000                      NaN
# 56001                      NaN
# 56002                      NaN
#
# [5 rows x 49 columns]

# %%
#4) Show the last record of the location  'world' 
# And show total cases, total deaths, population, life_expectancy from the location 'World' ( 4 pts)
res = world.iloc[-1]
res

print("Total covid cases in the world:", res['total_cases'])
print("Total covid total_deaths cases in the world:", res['total_deaths'])
print("Population of the world:", res['population'])
print("life_expectancy of the world:", res['life_expectancy'])
# Out:
# Total covid cases in the world: 52143259.0
# Total covid total_deaths cases in the world: 1284610.0
# Population of the world: 7794798729.0
# life_expectancy of the world: 72.58

# %%
#5) Show how many countries(location) names
#  (remove the duplicate and world) in the dataset ( 2 pts)

number = random.randint(0,10000)
print("You name , id: ", number )
print('------------------------------')

df = df[ (df['location'] != 'World') ]


names = df['location'].unique()
len(names)
print("The number of countries(locations) in the dataset: ",len(names)) 
print()

#for name in names:
#    print(name)
# Out:
# You name , id:  7422
# ------------------------------
# The number of countries(location) names in the dataset:  215

# %%
#6) Show all the countries(location) names
# (remove the duplicate and world) in the dataset ( 2 pts)

number = random.randint(0,10000)
print("You name , id: ", number )
print('------------------------------')
number = random.randint(0,10000)
print("You name , id: ", number )
print('------------------------------')

data = df[df['location'] != 'World']
print(len(data))
num = data['new_cases'].sum()
print('Show the totol number of convid cases in the world', num)
# Out:
# You name , id:  1348
# ------------------------------
# 56003
# Show the totol number of convid cases in the world 52140221.0

# %%
#8) Show the totol number of deaths in the world
# (Make sure not include the location 'world', add new_deaths from each location)
# Compare your result with problem 3)

number = random.randint(0,10000)
print("You name , id: ", number )
print('------------------------------')

data = df[df['location'] != 'World']

num = data['new_deaths'].sum()
print('Show the totol number of convid deaths in the world')
num
# Out:
# You name , id:  8706
# ------------------------------
# Show the totol number of convid deaths in the world
# 1284436.0

# %%
#9) Show the death rate ( number of deaths/ total covid cases) in the world

number = random.randint(0,10000)
print("You name , id: ", number )
print('------------------------------')

data = df[df['location'] != 'World']
rate = data['new_deaths'].sum()/data['new_cases'].sum()
print('Show the death rate in the world')
print(format(rate,'.2%' ))
# Out:
# You name , id:  2637
# ------------------------------
# Show the death rate in the world
# 2.46%

# %%
# 10) Show the average median age of the world, the average life expectancy in worldwide
number = random.randint(0,10000)
print("You name , id: ", number )
print('------------------------------')

age = df['median_age'].mean()
print('Show the average median_age of the world')
print(format(age, '.0f'))

life_expectancy = df['life_expectancy'].mean()
print('Show the average life expectancy of the world')
print(format(life_expectancy, '.0f'))
# Out:
# You name , id:  2541
# ------------------------------
# Show the average median_age of the world
# 31
# Show the average life expectancy of the world
# 74

# %% [markdown]
# # B) Basic Statistics for a country (Select your own country)
# # ( 30 points)
#
# # For example, I chose Brazil

# %%
# Show number of records for Brazil in this dataset 
import random
number = random.randint(0,10000)
print("You name , id: ", number )
print('------------------------------')

res = df[df['location']=='Brazil']
print("Number of records:" ,len(res))
res
# Out:
# You name , id:  4215
# ------------------------------
# Number of records: 318
#      iso_code      continent location        date  total_cases  new_cases  \
# 7202      BRA  South America   Brazil  2019-12-31          NaN        0.0
# 7203      BRA  South America   Brazil  2020-01-01          NaN        0.0
# ...       ...            ...      ...         ...          ...        ...
# 7518      BRA  South America   Brazil  2020-11-11    5664115.0    10554.0
# 7519      BRA  South America   Brazil  2020-11-12    5675032.0    10917.0
#
#       new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 7202                 NaN           NaN         0.0                  NaN  ...
# 7203                 NaN           NaN         0.0                  NaN  ...
# ...                  ...           ...         ...                  ...  ...
# 7518           14009.429      162397.0       128.0              271.571  ...
# 7519           12143.857      162628.0       231.0              217.429  ...
#
#       gdp_per_capita  extreme_poverty  cardiovasc_death_rate  \
# 7202       14103.452              3.4                177.961
# 7203       14103.452              3.4                177.961
# ...              ...              ...                    ...
# 7518       14103.452              3.4                177.961
# 7519       14103.452              3.4                177.961
#
#       diabetes_prevalence  female_smokers  male_smokers  \
# 7202                 8.11            10.1          17.9
# 7203                 8.11            10.1          17.9
# ...                   ...             ...           ...
# 7518                 8.11            10.1          17.9
# 7519                 8.11            10.1          17.9
#
#       handwashing_facilities  hospital_beds_per_thousand  life_expectancy  \
# 7202                     NaN                         2.2            75.88
# 7203                     NaN                         2.2            75.88
# ...                      ...                         ...              ...
# 7518                     NaN                         2.2            75.88
# 7519                     NaN                         2.2            75.88
#
#       human_development_index
# 7202                    0.759
# 7203                    0.759
# ...                       ...
# 7518                    0.759
# 7519                    0.759
#
# [318 rows x 49 columns]

# %%
#1) Show the totol number of covid cases in Brazil ( 3 pts)

number = random.randint(0,10000)
print("You name , id: ", number )
print('------------------------------')

res = df[df['location']=='Brazil']

num = res['new_cases'].sum()
print('The totol number of convid cases in Brazil:', format(num, '.0f'))
# Out:
# You name , id:  8790
# ------------------------------
# Show the totol number of convid cases in Brazil: 5675032

# %%
#2) Show the totol number of covid deaths in Brazil ( 3 pts)

number = random.randint(0,10000)
print("You name , id: ", number )
print('------------------------------')

res = df[df['location']=='Brazil']
num = res['new_deaths'].sum()
print('The totol number of convid deaths in Brazil')
print(format(num, '.0f'))
# Out:
# You name , id:  1063
# ------------------------------
# Show the totol number of convid deaths in Brazil
# 162628

# %%
# 3-4) Show the death rate in Brazil (3 pts)
# Is it above or lower than the worldwide death rate? (3 pts)

number = random.randint(0,10000)
print("You name , id: ", number )
print('------------------------------')

res = df[df['location']=='Brazil']

tot_new_cases = res['new_cases'].sum()

res = df[df['location']=='Brazil']
tot_new_deaths = res['new_deaths'].sum()


rate1 = tot_new_deaths / tot_new_cases
print('Show the death rate in Brazil')
print(format(rate1,'.2%' ))


rate2 = df['new_deaths'].sum()/df['new_cases'].sum()
print('Show the death rate in the world')
print(format(rate2,'.2%' ))

if rate1 > rate2:
    print("Brazil is above the world level")
else:
    print("Brazil is below the world level")
# Out:
# You name , id:  9890
# ------------------------------
# Show the death rate in Brazil
# 2.87%
# Show the death rate in the world
# 2.46%
# Brazil is above the world level

# %%
# 5-6) Show the average new_cases_per_million people in Brazil 
# Is it above or lower than the worldwide level.
# (6 pts)

number = random.randint(0,10000)
print("You name , id: ", number )
print('------------------------------')


res = df[df['location']=='Brazil']

num1 = res['new_cases_per_million'].mean()
print('Show the average new cases per million in Brazil')
print(format(num1, '.0f'))

num2 = df['new_cases_per_million'].mean()
print('Show the average new cases per million in the world')
print(format(num2, '.0f'))


if num1 > num2:
    print("Brazil is above the world level")
else:
    print("Brazil is below the world level")
# Out:
# You name , id:  1334
# ------------------------------
# Show the average new cases per million in Brazil
# 84
# Show the average new cases per million in the world
# 38
# Brazil is above the world level

# %%
# 7-8) Show the life_expectancy in Brazil, 
# and compare it to the average of life_expectancy in the world
#(6 pts)
number = random.randint(0,10000)
print("You name , id: ", number )
print('------------------------------')


res = df[df['location']=='Brazil']
#print(res)

#num1 = res['life_expectancy'].iloc[0]   
num1 = res['life_expectancy'].mean()
print('Show the life expectancy of the Brazil')
print(format(num1, '.1f'))

num2 = df['life_expectancy'].mean()     
print('Show the life expectancy of the world')
print(format(num2, '.1f'))


if num1 > num2:
    print("Brazil is above the world level")
else:
    print("Brazil is below the world level")
# Out:
# You name , id:  1652
# ------------------------------
# Show the life expectancy of the Brazil
# 75.9
# Show the life expectancy of the world
# 74.0
# Brazil is above the world level

# %%
# 9) Show the Brazil's population and population of aged 70 older (3 pts)
# 10) What is the percentage of population in aged_70_older in Brazil? (3 pts)
number = random.randint(0,10000)
print("You name , id: ", number )
print('------------------------------')

res = df[df['location']=='Brazil']

#total = res['population'].unique()[0]
# brazil population
total_pop = res['population'].mean() 

print('The population of Brazil:',format(total_pop, '.0f'))

#pop2 = res['aged_70_older'].iloc[0]     # Same
old_pop = res['aged_70_older'].mean()

print('Show the population of aged 70 older in Brazil')
old_pop = old_pop*1000000
print(format(old_pop, '.0f'))

print("Pencentage is" , format(old_pop/total_pop, '.1%'))
#print()
# Out:
# You name , id:  8898
# ------------------------------
# The population of Brazil: 212559409
# Show the population of aged 70 older in Brazil
# 5060000
# Pencentage is 2.4%

# %%
# 11) How many days which new cases are over 1000
# How many days which new cases are over 10000

res = df [ (df['location']=='Brazil') & (df['new_cases']>5000) ]
print("How many days which new cases is over 5000 in Brazil")
print(len(res))

res = df [ (df['location']=='Brazil') & (df['new_cases']>10000) ]
print("How many days which new cases is over 10000 in Brazil")
print(len(res))
# Out:
# How many days which new cases is over 5000 in Brazil
# 212
# How many days which new cases is over 10000 in Brazil
# 196
